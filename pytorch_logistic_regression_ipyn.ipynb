# %%
# Install pyTorch (Google CoLab)
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision

# Import important libraries
import torch
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt

# Our dataset
x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0], [4.0]]))
y_data = Variable(torch.Tensor([[0.], [0.], [1.0], [1.0]]))
             
  
class Model(torch.nn.Module):
  def __init__(self):
    super(Model, self).__init__()
    self.linear = torch.nn.Linear(1, 1)
    
  def forward(self, x):
    y_pred = F.sigmoid(self.linear(x))
    return y_pred
  
model = Model()

# Unlike a simple linear regression, logistic regression is better used
# with a cross entropy loss function: BCELoss binary cross entropy loss
# Gradient descent will still be used here to minimize loss
criterion = torch.nn.BCELoss(size_average=False)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    
for epoch in range(500):
  # Forward pass: Compute predicted y and update weights
  y_pred = model.forward(x_data)
  
  # Compute loss
  loss = criterion(y_pred, y_data)
  print(epoch, loss.data[0])
  
  # Zero grad, backpropagate, update weights
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

    
# Test our model
hour_var = Variable(torch.Tensor([1.0]))
print("Predict 1 hour {0}".format(model(hour_var).data[0] > 0.5))

hour_var = Variable(torch.Tensor([7.0]))
print("Predict 7 hour {0}".format(model(hour_var).data[0] > 0.5))
# Out:
# 0 2.704812526702881
# 1 2.683973789215088
# 2 2.6657509803771973
# 3 2.6497206687927246
# 4 2.6355292797088623
# 5 2.622882604598999
# 6 2.611534357070923
# 7 2.6012799739837646
# 8 2.5919485092163086
# 9 2.5833957195281982
# 10 2.575502872467041
# 11 2.568169116973877
# 12 2.561310052871704
# 13 2.5548551082611084
# 14 2.548743963241577
# 15 2.5429275035858154
# 16 2.5373623371124268
# 17 2.532012939453125
# 18 2.5268492698669434
# 19 2.5218448638916016
# 20 2.5169785022735596
# 21 2.5122315883636475
# 22 2.5075881481170654
# 23 2.503035068511963
# 24 2.498560905456543
# 25 2.4941556453704834
# 26 2.489811420440674
# 27 2.485520601272583
# 28 2.4812772274017334
# 29 2.477077007293701
# 30 2.472914218902588
# 31 2.468785524368286
# 32 2.4646880626678467
# 33 2.4606189727783203
# 34 2.4565749168395996
# 35 2.452554941177368
# 36 2.448556423187256
# 37 2.4445784091949463
# 38 2.4406192302703857
# 39 2.4366776943206787
# 40 2.432753086090088
# 41 2.428844690322876
# ...

# %%
hour_var = Variable(torch.Tensor([1.0]))
print("Predict 1 hour {0}".format(model(hour_var).data[0] > 0.5))
# Out:
# Predict 1 hour False
